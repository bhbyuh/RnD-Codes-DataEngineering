# %% [markdown]
# ## Databricks utilities (dbuitls)

# %%
# utilities only work with pyhon , scala, not with sql
# All available utlilites 
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
# ...

# %%
# File System utitlities

dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
# -- this list contant available in directory
display(dbutils.fs.ls('/')) # it will show default root databricks file sysrem
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Workspace/</td><td>Workspace/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("abfss://unitycatalog@muaazexternalstorage.dfs.core.windows.net/external_table"))

# %%
dbutils.widgets.help()

# %%
#. Widgets are for tking input in notebook
dbutils.widgets.text("input_name", "")

# %%
name=dbutils.widgets.get("input_name")

# %%
# secrets utilities
dbutils.secrets.help()

# %%
# notebook utilities
dbutils.notebook.help()

# %% [markdown]
# ## Secrets

# %%
dbutils.secrets.help()
# Out:
# <div class = "ansiout">
# Provides utilities for leveraging secrets within notebooks.
# Databricks documentation for more info.
#     <h3></h3><b>get(scope: String, key: String): String</b> -> Gets the string representation of a secret value with scope and key<br /><b>get(catalog: String, schema: String, key: String): String</b> -> Gets the string representation of a unity catalog secret value<br /><b>getBytes(scope: String, key: String): byte[]</b> -> Gets the bytes representation of a secret value with scope and key<br /><b>getBytes(catalog: String, schema: String, key: String): byte[]</b> -> Gets the bytes representation of a unity catalog secret value<br /><b>list(scope: String): Seq</b> -> Lists secret metadata for secrets within a scope<br /><b>list(catalog: String, schema: String): Seq</b> -> Lists secret metadata for unity catalog secrets within a catalog and schema<br /><b>listScopes: Seq</b> -> Lists secret scopes<br /><br /></div>

# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='testscope')]

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()

w.secrets.put_secret("testscope","db-password",string_value="123")

# %%
dbutils.secrets.list("testscope")
# Out:
# [SecretMetadata(key='db-password')]

# %%
password = dbutils.secrets.get(scope = "testscope", key = "db-password")

# %%
dbutils.secrets.get(scope = "testscope", key = "db-password")
# Out:
# '[REDACTED]'
